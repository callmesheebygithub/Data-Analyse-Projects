# %% [markdown]
# # Simple Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Upload Dataset

# %%
data=pd.read_csv('titanic.csv',usecols=['Age','SibSp','Parch'])
data.sample(5)
# Out:
#       Age  SibSp  Parch
# 138  16.0      0      0
# 639   NaN      1      0
# 714  52.0      0      0
# 799  30.0      1      1
# 749  31.0      0      0

# %%
data['Family']=data['SibSp']+data['Parch']

# %%
data.drop(['SibSp','Parch'],axis=1,inplace=True)

# %% [markdown]
# ## Data Analysis

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
data.shape
# Out:
# Number of Rows 891
# Number of Columns 2
# (891, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     714 non-null    float64
#  1   Family  891 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 14.0 KB

# %%
data.describe()
# Out:
#               Age      Family
# count  714.000000  891.000000
# mean    29.699118    0.904602
# std     14.526497    1.613459
# min      0.420000    0.000000
# 25%     20.125000    0.000000
# 50%     28.000000    0.000000
# 75%     38.000000    1.000000
# max     80.000000   10.000000

# %%
data.corr()
# Out:
#              Age    Family
# Age     1.000000 -0.301914
# Family -0.301914  1.000000

# %% [markdown]
# ## Data Cleaning

# %%
print("Is there any Null value\n",data.isnull().any())
# Out:
# Is there any Null value
#  Age        True
# Family    False
# dtype: bool

# %%
data.dropna(subset=['Age'],axis=0,how="any",inplace=True)

# %%
data.shape
# Out:
# (714, 2)

# %% [markdown]
# ## Data visualize

# %%
fig,(ax1,ax2,ax3,ax4)=plt.subplots(ncols=4,figsize=(12,3))

sns.barplot(data=data,ax=ax1)
sns.kdeplot(data=data,ax=ax2)
sns.scatterplot(data=data,ax=ax3)
sns.boxplot(data=data,ax=ax4)
plt.show()

# %%
X=data.drop("Family",axis=1)
y=data['Family']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)
print('x_train',x_train.shape)
print('x_test',x_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# x_train (499, 1)
# x_test (215, 1)
# y_train (499,)
# y_test (215,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

sc.fit(x_train)

x_train_sc=sc.transform(x_train)
x_test_sc=sc.transform(x_test)

# %%
x_train_sc=pd.DataFrame(x_train_sc,columns=x_train.columns)
x_test_sc=pd.DataFrame(x_test_sc,columns=x_test.columns)

# %%
fig,(ax1,ax2,ax3,ax4)=plt.subplots(ncols=4,figsize=(12,3))

sns.barplot(data=x_train_sc,ax=ax1)
sns.kdeplot(data=x_train_sc,ax=ax2)
sns.scatterplot(data=x_train_sc,ax=ax3)
sns.boxplot(data=x_train_sc,ax=ax4)

plt.show()

# %%
data.skew()
# Out:
# Age       0.389108
# Family    2.010600
# dtype: float64

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))

sns.distplot(data['Age'],ax=ax1)
sns.distplot(data['Family'],ax=ax2)


plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
upper_limit_age=data['Age'].quantile(0.99)
lower_limit_age=data['Age'].quantile(0.01)
print("upper_limit_age",upper_limit_age)
print("lower_limit_age",lower_limit_age)
# Out:
# upper_limit_age 65.87
# lower_limit_age 1.0

# %%
new_data=data[(data['Age']>=1.0) & (data['Age']<=63.999)]

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))

ax1.set_title('Before Remove outliers')
sns.boxplot(data['Age'],ax=ax1)
ax2.set_title("After Remove Outliers")
sns.boxplot(new_data['Age'],ax=ax2)


plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(new_data['Age'],new_data['Family'],kind="reg")
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data['Family'],data['Age'],kind="reg")
plt.show()
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Now Working on Predict the Data

# %%
lr=LinearRegression()

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([ 1.00625798,  0.27760464,  1.903164  ,  0.74129313,  1.07249919,
#         0.74129313,  0.90689616, -0.21920446, -0.21920446,  0.37696646,
#         1.20498162,  1.07249919,  1.80115253,  0.64193131,  1.23810222,
#         0.1120016 ,  0.84065495,  1.90879451,  1.1387404 ,  0.64193131,
#         1.27122283,  0.6088107 ,  1.46994647,  0.97313737,  0.94001677,
#         1.90879451,  0.74129313,  1.23810222,  1.03937859,  0.6088107 ,
#         0.87377555,  1.86739375,  1.27122283,  0.21136342,  0.77441373,
#         0.54256949,  0.67505191,  0.74129313,  1.27122283,  1.43682586,
#         1.20498162,  1.23810222,  0.54256949,  1.23810222,  1.00625798,
#         1.76803193,  1.83427314,  1.1387404 ,  0.77441373,  1.00625798,
#         0.67505191,  1.1387404 ,  1.1056198 ,  0.87377555,  0.04576039,
#         1.1056198 ,  1.50306708,  1.1056198 , -0.11984264,  0.54256949,
#         0.67505191,  0.24448403,  1.07249919,  1.27122283,  1.40370526,
#         0.97313737,  0.6088107 ,  0.77441373,  1.86739375,  1.17186101,
#         1.20498162,  0.74129313,  1.33746404,  0.64193131,  0.01263978,
#         1.03937859,  1.33746404,  1.30434344,  0.97313737,  1.17186101,
#         1.91972431,  0.31072524,  0.44320767,  0.84065495,  0.01263978,
#         1.1387404 ,  0.80753434,  0.64193131,  0.90689616,  0.04576039,
#         1.20498162,  1.15530071,  1.17186101,  1.66867011, -0.11984264,
#         1.80115253,  0.84065495,  1.33746404,  1.07249919,  0.87377555,
#         1.1387404 ,  1.00625798,  0.44320767,  0.74129313,  1.30434344,
#         0.97313737,  1.1387404 ,  0.27760464,  0.50944888,  1.40370526,
#         1.23810222,  1.03937859,  1.80115253,  0.74129313, -0.18608385,
#         0.87377555,  0.80753434,  0.57569009,  0.80753434,  1.37058465,
#         1.30434344,  1.00625798,  1.07249919,  1.00625798,  0.21136342,
#         0.74129313,  1.80115253,  0.34384585,  0.50944888,  0.74129313,
#        -0.05360143,  0.44320767,  1.03937859,  0.77441373,  1.03937859,
#         1.23810222,  0.90689616,  1.76803193,  0.94001677,  1.30434344,
#         0.85721525,  0.67505191,  1.1387404 ,  0.74129313,  1.1056198 ,
#         0.77441373,  0.42664737,  0.90689616,  0.94001677,  1.20498162,
#         1.20498162,  1.03937859,  0.50944888,  1.27122283,  1.33746404,
#         1.20498162,  1.56930829,  0.97313737,  1.1221801 ,  1.37058465,
#         1.27122283,  0.078881  ,  1.23810222,  1.86739375,  0.94001677,
#         1.30434344,  0.31072524,  0.74129313,  1.66867011, -0.71601356,
#         0.27760464,  1.33746404,  1.20498162,  1.1056198 ,  1.43682586,
#         0.80753434,  1.43682586,  1.1387404 ,  0.70817252,  1.70179071,
#         0.44320767,  1.23810222,  1.1056198 ,  1.00625798, -0.02048082,
#         0.27760464,  1.40370526,  1.1387404 ,  1.66867011,  1.1056198 ,
#         0.94001677,  1.03937859,  1.07249919,  1.30434344,  0.92345646,
#         1.30434344,  0.01263978,  0.44320767,  1.03937859,  0.44320767,
#         0.94001677,  0.90689616,  0.47632827,  0.94001677,  0.84065495,
#         0.80753434,  0.70817252,  0.64193131,  1.50306708,  0.64193131,
#         0.42664737,  1.1387404 ,  1.07249919,  0.078881  , -0.38480749])

# %%
print("Mean Absolute Error (MAE)",mean_absolute_error(y_test,y_pred))
print("Mean Squared Error (MSE)",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# Mean Absolute Error (MAE) 1.0080686464539867
# Mean Squared Error (MSE) 1.747896431460193
# R2 score 0.0682414310924715

# %%
## y_test or y_pred convert into dataset
comparing=pd.DataFrame({"Actual":y_test,"Prediction":y_pred})
comparing.sample(5)
# Out:
#      Actual  Prediction
# 535       2    1.701791
# 471       0    0.675052
# 232       0   -0.020481
# 305       3    1.903164
# 89        0    1.138740

# %%
comparing.describe().round(1)
# Out:
#        Actual  Prediction
# count   215.0       215.0
# mean      0.9         0.9
# std       1.4         0.5
# min       0.0        -0.7
# 25%       0.0         0.7
# 50%       0.0         1.0
# 75%       1.0         1.2
# max       6.0         1.9

# %%
sns.kdeplot(data=comparing)
plt.show()

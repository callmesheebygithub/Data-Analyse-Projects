# %% [markdown]
# # Project_3

# %% [markdown]
# **learning materials**
# In this project, we will discuss:
# - How to fetch random samples from the Dataset?
# - isin
# - between
# - unique
# - dropna
# - replace
# - duplicated
# - drop_duplicates
# - astype
# - apply
# - What is Univariate analysis?
# - What is Bivariate analysis?
# - Memory Optimization **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('adult.csv')

# %% [markdown]
# # 1.Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# # 2. Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (48842, 15)

# %%
print('NUMBER OF ROWS', data.shape[0])
print('NUMBER OF columns', data.shape[1])
# Out:
# NUMBER OF ROWS 48842
# NUMBER OF columns 15

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # 5. Fetch Random Sample From the Dataset (50%)

# %%
data.sample(frac=0.50)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 32595   52     Local-gov   43909       HS-grad                9
# 24856   64  Self-emp-inc  181408     Assoc-voc               11
# 33571   31       Private  132601       HS-grad                9
# 45226   17       Private  147069          10th                6
# 7068    26     State-gov  232914  Some-college               10
# ...    ...           ...     ...           ...              ...
# 42885   24       Private  322674    Assoc-acdm               12
# 26329   31   Federal-gov  210926       HS-grad                9
# 29050   44     Local-gov  101967       Masters               14
# 41020   17       Private  165918          11th                7
# 48757   35       Private   30673          12th                8
#
#            marital-status         occupation   relationship   race  gender  \
# 32595            Divorced       Adm-clerical      Unmarried  Black  Female
# ...

# %%
data.sample(frac=0.50,random_state=100)
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 12393   37    Private  110331   Prof-school               15
# 48701   23    Private   45834     Bachelors               13
# 17918   28    Private   89718       HS-grad                9
# 11352   30    Private  351770           9th                5
# 36198   31    Private  164190          10th                6
# ...    ...        ...     ...           ...              ...
# 48573   41    Private  318046  Some-college               10
# 47252   41  Local-gov   33658  Some-college               10
# 33142   69    Private  312653  Some-college               10
# 2965    21          ?  334593  Some-college               10
# 32089   34    Private  186269       HS-grad                9
#
#            marital-status        occupation   relationship   race  gender  \
# 12393  Married-civ-spouse     Other-service           Wife  White  Female
# 48701       Never-married   Exec-managerial  Not-in-family  White  Female
# ...

# %% [markdown]
# # 6.Check Null Values In The Dataset

# %%
data.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %% [markdown]
# # 7.Perform Data Cleaning [ Replace '?' with NaN ]

# %%
data.head(50)
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 0    25           Private  226802          11th                7
# 1    38           Private   89814       HS-grad                9
# 2    28         Local-gov  336951    Assoc-acdm               12
# 3    44           Private  160323  Some-college               10
# 4    18                 ?  103497  Some-college               10
# 5    34           Private  198693          10th                6
# 6    29                 ?  227026       HS-grad                9
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 8    24           Private  369667  Some-college               10
# 9    55           Private  104996       7th-8th                4
# 10   65           Private  184454       HS-grad                9
# 11   36       Federal-gov  212465     Bachelors               13
# 12   26           Private   82091       HS-grad                9
# ...

# %%
data.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
import numpy as np

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['workclass']=data['workclass'].replace('?',np.NAN)

# %%
data['occupation']=data['occupation'].replace('?',np.NAN)

# %%
data['native-country']=data['native-country'].replace('?',np.NAN)
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# # 8. Drop all The Missing Values

# %%
missing=data.isnull().sum()*100/len(data)

# %%
missing
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
data.dropna(how='any',inplace=True)

# %%
data.shape
# Out:
# (45222, 15)

# %% [markdown]
# # 9. Check For Duplicate Data and Drop Them

# %%
dup=data.duplicated().any()
print('Are there any duplicated values',dup)
# Out:
# Are there any duplicated values True

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (45175, 15)

# %% [markdown]
# # 10. Get Overall Statistics About The Dataframe

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# # 11. Drop The Columns education-num, capital-gain, and capital-loss

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data=data.drop(['educational-num','capital-gain','capital-loss'], axis=1)

# %%
data
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %% [markdown]
# # UNIVERSAL ANALYSIS

# %% [markdown]
# # 12. What Is The Distribution of Age Column?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data['age'].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %% [markdown]
# # 13. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
(data['age']>16) &(data['age']<49)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 5         True
#          ...
# 48837     True
# 48838     True
# 48839    False
# 48840     True
# 48841    False
# Name: age, Length: 45175, dtype: bool

# %%
data[(data['age']>16) &(data['age']<49)]
# Out:
#        age  workclass  fnlwgt     education      marital-status  \
# 0       25    Private  226802          11th       Never-married
# 1       38    Private   89814       HS-grad  Married-civ-spouse
# 2       28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44    Private  160323  Some-college  Married-civ-spouse
# 5       34    Private  198693          10th       Never-married
# ...    ...        ...     ...           ...                 ...
# 48834   32    Private  116138       Masters       Never-married
# 48836   22    Private  310152  Some-college       Never-married
# 48837   27    Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40    Private  154374       HS-grad  Married-civ-spouse
# 48840   22    Private  201490       HS-grad       Never-married
#
#               occupation   relationship                race  gender  \
# 0      Machine-op-inspct      Own-child               Black    Male
# ...

# %%
sum((data['age']>16) &(data['age']<49))
# Out:
# 34858

# %%
data['age'].between(17,48)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 5         True
#          ...
# 48837     True
# 48838     True
# 48839    False
# 48840     True
# 48841    False
# Name: age, Length: 45175, dtype: bool

# %%
sum(data['age'].between(17,48))
# Out:
# 34858

# %%
x=data['age']
y=data['income']
plt.bar(x,y, width=0.2)
plt.figure(figsize=(16,9))
plt.show()

# %% [markdown]
# # 14. What is The Distribution of Workclass Column?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data['workclass'].describe()
# Out:
# count       45175
# unique          7
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %% [markdown]
# # 15. How Many Persons Having Bachelors and Masters Degree?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data[data['education'].str.contains('Bachelors',case=False)].count()
# Out:
# age               7559
# workclass         7559
# fnlwgt            7559
# education         7559
# marital-status    7559
# occupation        7559
# relationship      7559
# race              7559
# gender            7559
# hours-per-week    7559
# native-country    7559
# income            7559
# dtype: int64

# %%
data[data['education'].str.contains('Bachelors',case=False)]
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 11      36       Federal-gov  212465  Bachelors  Married-civ-spouse
# 20      34           Private  107914  Bachelors  Married-civ-spouse
# 23      25           Private  220931  Bachelors       Never-married
# 24      25           Private  205947  Bachelors  Married-civ-spouse
# 32      24  Self-emp-not-inc  188274  Bachelors       Never-married
# ...    ...               ...     ...        ...                 ...
# 48788   50           Private  302372  Bachelors  Married-civ-spouse
# 48792   25         Local-gov  514716  Bachelors       Never-married
# 48814   54           Private  337992  Bachelors  Married-civ-spouse
# 48817   34           Private  160216  Bachelors       Never-married
# 48819   38           Private  139180  Bachelors            Divorced
#
#             occupation   relationship                race  gender  \
# 11        Adm-clerical        Husband               White    Male
# ...

# %%
data[data['education'].str.contains('Masters',case=False)]
# Out:
#        age workclass  fnlwgt education      marital-status       occupation  \
# 15      43   Private  346189   Masters  Married-civ-spouse  Exec-managerial
# 40      65   Private  136384   Masters  Married-civ-spouse   Prof-specialty
# 62      26   Private   31208   Masters       Never-married  Exec-managerial
# 92      33   Private  176410   Masters  Married-civ-spouse   Prof-specialty
# 94      34   Private  198751   Masters       Never-married    Other-service
# ...    ...       ...     ...       ...                 ...              ...
# 48785   50   Private  208630   Masters            Divorced            Sales
# 48794   46   Private   42972   Masters  Married-civ-spouse   Prof-specialty
# 48825   31   Private  199655   Masters            Divorced    Other-service
# 48834   32   Private  116138   Masters       Never-married     Tech-support
# 48835   53   Private  321865   Masters  Married-civ-spouse  Exec-managerial
#
# ...

# %%
len(data[data['education'].str.contains('Masters',case=False)])
# Out:
# 2513

# %%
data[data['education'].isin(['Masters','Bachelors'])]
# Out:
#        age    workclass  fnlwgt  education      marital-status  \
# 11      36  Federal-gov  212465  Bachelors  Married-civ-spouse
# 15      43      Private  346189    Masters  Married-civ-spouse
# 20      34      Private  107914  Bachelors  Married-civ-spouse
# 23      25      Private  220931  Bachelors       Never-married
# 24      25      Private  205947  Bachelors  Married-civ-spouse
# ...    ...          ...     ...        ...                 ...
# 48817   34      Private  160216  Bachelors       Never-married
# 48819   38      Private  139180  Bachelors            Divorced
# 48825   31      Private  199655    Masters            Divorced
# 48834   32      Private  116138    Masters       Never-married
# 48835   53      Private  321865    Masters  Married-civ-spouse
#
#             occupation   relationship                race  gender  \
# 11        Adm-clerical        Husband               White    Male
# 15     Exec-managerial        Husband               White    Male
# ...

# %%
len(data[data['education'].isin(['Masters','Bachelors'])])
# Out:
# 10072

# %% [markdown]
# # 17. Replace Salary Values With 0 and 1

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
def salary_data(sal):
    if sal=='>50K':
        return 0
    else:
        return 1

# %%
data['Encoded_Salary']=data['income'].apply(salary_data)

# %%
data.head(5)
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 5   34    Private  198693          10th       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country income  Encoded_Salary
# 0  United-States  <=50K               1
# 1  United-States  <=50K               1
# 2  United-States   >50K               0
# 3  United-States   >50K               0
# ...

# %%
data.replace(to_replace=['<=50K', '>50K'],value=[0,1],inplace=True)

# %%
data.head(2)
# Out:
#    age workclass  fnlwgt education      marital-status         occupation  \
# 0   25   Private  226802      11th       Never-married  Machine-op-inspct
# 1   38   Private   89814   HS-grad  Married-civ-spouse    Farming-fishing
#
#   relationship   race gender  hours-per-week native-country  income  \
# 0    Own-child  Black   Male              40  United-States       0
# 1      Husband  White   Male              50  United-States       0
#
#    Encoded_Salary
# 0               1
# 1               1

# %% [markdown]
# # 18. Which Workclass Getting The Highest Salary?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'Encoded_Salary'],
#       dtype='object')

# %%
data.groupby('workclass')['income'].mean()
# Out:
# workclass
# Federal-gov         0.390469
# Local-gov           0.295161
# Private             0.217816
# Self-emp-inc        0.554407
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Without-pay         0.095238
# Name: income, dtype: float64

# %%
data.groupby('workclass')['income'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554407
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Private             0.217816
# Without-pay         0.095238
# Name: income, dtype: float64

# %% [markdown]
# # 19.How Has Better Chance To Get Salary greater than 50K Male or Female?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'Encoded_Salary'],
#       dtype='object')

# %%
data.groupby('gender')['income'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.312609
# Female    0.113692
# Name: income, dtype: float64

# %% [markdown]
# # 20. Covert workclass Columns Datatype To Category Datatype

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  object
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  int64
#  12  Encoded_Salary  45175 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 4.8+ MB

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'Encoded_Salary'],
#       dtype='object')

# %%
data['workclass']=data['workclass'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  category
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income          45175 non-null  int64
#  12  Encoded_Salary  45175 non-null  int64
# dtypes: category(1), int64(5), object(7)
# memory usage: 4.5+ MB

# %% [markdown]
# # Material Status

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'Encoded_Salary'],
#       dtype='object')

# %%
data['marital-status']
# Out:
# 0             Never-married
# 1        Married-civ-spouse
# 2        Married-civ-spouse
# 3        Married-civ-spouse
# 5             Never-married
#                 ...
# 48837    Married-civ-spouse
# 48838    Married-civ-spouse
# 48839               Widowed
# 48840         Never-married
# 48841    Married-civ-spouse
# Name: marital-status, Length: 45175, dtype: object

# %%
data['marital-status'].drop_duplicates()
# Out:
# 0              Never-married
# 1         Married-civ-spouse
# 18                   Widowed
# 27                 Separated
# 34                  Divorced
# 54     Married-spouse-absent
# 382        Married-AF-spouse
# Name: marital-status, dtype: object

# %%
x=['Married-AF-spouse','Married-spouse-absent','Divorced','Separated','Widowed','Married-civ-spouse']
y=[382 ,54,34,27,18,1]
colors=["g", 'b','r','y','c','m'] 
plt.figure(figsize=(12,7))
explode=[0.02,0.02,0.02,0.02,0.02,0.3]
textprops={"fontsize":12}
plt.pie(y,labels=x , colors=colors ,explode=explode ,textprops=textprops,
       radius=1 ,autopct="%0.02f%%", shadow=False, startangle=180)
plt.legend()
plt.show()

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'Encoded_Salary'],
#       dtype='object')

# %%
data['relationship'].drop_duplicates()
# Out:
# 0           Own-child
# 1             Husband
# 5       Not-in-family
# 8           Unmarried
# 17               Wife
# 217    Other-relative
# Name: relationship, dtype: object

# %% [markdown]
# # Relationship Status

# %%
x=['Other-relative','Wife','Unmarried',' Not-in-family','Husband']
y=[217,17,8,5,1]
explode=[0.05,0.02,0.02,0.02,0.03]
colors=["g", 'b','r','y','k']
plt.pie(y,labels=x, startangle=180, radius=1.5,autopct="%0.1f%%",explode=explode,colors=colors)
plt.legend()
plt.show()

# %% [markdown]
# # Material status + Relationship Status showing through Scatterplot

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'Encoded_Salary'],
#       dtype='object')

# %%
# data['marital-status'].drop_duplicates()

# %%
# data['relationship'].drop_duplicates()

# %%
x=['Other-relative','Wife','Unmarried',' Not-in-family','Husband','Married-AF-spouse','Married-spouse-absent','Divorced','Separated','Widowed','Married-civ-spouse']
y=[217,17,8,5,1,382 ,54,34,27,18,1]
plt.scatter(y,x, c='g', alpha=1)
plt.title('Material status + Relationship Status showing through Scatterplot')
plt.xlabel('Average')
plt.show()

# %% [markdown]
# # Employee Belong to which country Most

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'Encoded_Salary'],
#       dtype='object')

# %%
# data.pivot_table(index=['native-country'], aggfunc='size')

# %%
x=['Yugoslavia','Vietnam','United-States','Trinadad&Tobago','Thailand','Taiwan','South','Scotland','Puerto-Rico','Portugal','Poland','Philippines','Philippines','Peru','Outlying-US(Guam-USVI-etc)','Nicaragua','Mexico','Laos','Japan','Jamaica','Italy ','Ireland','Iran','India','Hungary','Hungary','Hong','Honduras','Holand-Netherlands','Haiti','Guatemala','Greece','Germany','France','England','El-Salvador','Ecuador','Dominican-Republic','Cuba','Columbia','China','Canada','Cambodia']
y=[23,83,41256,26,29,55,101,20,175,34,65,62,81,282,45,22,48,895,21,89,103,100,36,56,147,18,28,19,1,69,84,49,193,36,119,147,43,97,133,82,113,163,26]
plt.figure(figsize=(16,12))
plt.barh(x,y,edgecolor="k")
plt.show()

# %%
# du=data.pivot_table(index=['gender'],aggfunc='size')
# print(du)

# %% [markdown]
# # After Drop Duplicate Country

# %%
x=['Holand-Netherlands','France','Outlying-US(Guam-USVI-etc)','Trinadad&Tobago','Greece',' Hong','Hungary','Yugoslavia','Ecuador','Jamaica','Scotland','Iran','Honduras','Nicaragua','China','Portugal','Canada','Italy','Taiwan','Cuba','England','Laos','Poland','Cambodia','India','Japan',' Columbia','South','Vietnam','Puerto-Rico','El-Salvador','Haiti','Thailand','Philippines','Germany','Ireland','Dominican-Republic','Mexico','Guatemala','Peru']
y=[35890,4228,3705,3308,2340,2219,2047,1911,1907,1748,1551,1161,1126,1030,945,890,868,794,729,586,544,498,473,417,398,396,385,377,309,301,296,237,232,220,141,128,74,46,37,23]
plt.figure(figsize=(18,12))
plt.barh(x,y, color='k',edgecolor='y')
plt.title("Employe And Country Relation",fontsize=24)
plt.xlabel('No_Of_Employee',fontsize=14)
plt.ylabel('Country',fontsize=26)
plt.show()

# %%
# age=data['age']
# workhour=data['hours-per-week']

# %%
# x=age
# y=workhour
# plt.scatter(x,y)
# plt.xlabel('Age')
# plt.ylabel('Work_Hour')
# plt.show()
